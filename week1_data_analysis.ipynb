# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
2+2
# Out:
# 4

# %%
df_can = pd.read_excel(r'C:\Users\shubham\Desktop\extra work\Python\.ipynb_checkpoints\Canada.xlsx',
                       sheet_name = 'Canada by Citizenship', skiprows= range(20), skipfooter= 2)

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.shape
# Out:
# (195, 43)

# %%
df_can.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
df_can.rename(columns ={'OdName':'Country', 'AreaName':'Continent'}, inplace = True)
df_can.columns
# Out:
# Index([     'Type',  'Coverage',   'Country',      'AREA', 'Continent',
#              'REG',   'RegName',       'DEV',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
#adding new column total
df_can['Total'] = df_can.sum(axis = 1)
df_can.head()
# Out:
#          Type    Coverage         Country  AREA Continent   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 1  Immigrants  Foreigners         Albania   908    Europe   925
# 2  Immigrants  Foreigners         Algeria   903    Africa   912
# 3  Immigrants  Foreigners  American Samoa   909   Oceania   957
# 4  Immigrants  Foreigners         Andorra   908    Europe   925
#
#            RegName  DEV             DevName  1980  ...  2005  2006  2007  \
# 0    Southern Asia  902  Developing regions    16  ...  3436  3009  2652
# 1  Southern Europe  901   Developed regions     1  ...  1223   856   702
# 2  Northern Africa  902  Developing regions    80  ...  3626  4807  3623
# 3        Polynesia  902  Developing regions     0  ...     0     1     0
# 4  Southern Europe  901   Developed regions     0  ...     0     1     1
#
#    2008  2009  2010  2011  2012  2013  Total
# 0  2111  1746  1758  2203  2635  2004  65977
# 1   560   716   561   539   620   603  18433
# ...

# %%
#to get the summary of data
df_can.describe()
# Out:
#              AREA          REG         DEV          1980          1981  \
# count  195.000000   195.000000  195.000000    195.000000    195.000000
# mean   912.764103  1249.015385  901.753846    508.394872    566.989744
# std     13.082835  1185.526885    0.431878   1949.588546   2152.643752
# min    903.000000   905.000000  901.000000      0.000000      0.000000
# 25%    903.000000   914.000000  902.000000      0.000000      0.000000
# 50%    908.000000   922.000000  902.000000     13.000000     10.000000
# 75%    922.000000   925.500000  902.000000    251.500000    295.500000
# max    935.000000  5501.000000  902.000000  22045.000000  24796.000000
#
#                1982          1983          1984         1985         1986  \
# count    195.000000    195.000000    195.000000   195.000000   195.000000
# mean     534.723077    387.435897    376.497436   358.861538   441.271795
# std     1866.997511   1204.333597   1198.246371  1079.309600  1225.576630
# ...

# %%
#filtering data as per column
df_can[['Country',2005,2006,2007,'Total']]
# Out:
#             Country  2005  2006  2007  Total
# 0       Afghanistan  3436  3009  2652  65977
# 1           Albania  1223   856   702  18433
# 2           Algeria  3626  4807  3623  72156
# 3    American Samoa     0     1     0   2774
# 4           Andorra     0     1     1   2749
# ..              ...   ...   ...   ...    ...
# 190        Viet Nam  1852  3153  2574  99903
# 191  Western Sahara     0     1     0   2719
# 192           Yemen   161   140   122   5744
# 193          Zambia    91    77    71   4392
# 194        Zimbabwe   615   454   663  11313
#
# [195 rows x 5 columns]

# %%
#Setting benchmark as Country 
# Easy to filterout the rows
df_can.set_index('Country', inplace = True)
df_can.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-cec18464c8fe> in <module>
#       1 #Setting benchmark as Country
#       2 # Easy to filterout the rows
# ----> 3 df_can.set_index('Country', inplace = True)
#       4 df_can.head(3)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
df_can.index.name = None

# %%
print(df_can.loc['Japan',[2010,2011,2012,2013]])
# Out:
# 2010    1168
# 2011    1265
# 2012    1214
# 2013     982
# Name: Japan, dtype: object

# %%
#filtering rows and columns
df_new = df_can[(df_can['Continent']== 'Asia') & (df_can['RegName']== 'Southern Asia')]

# %%
df_new[['Continent','RegName',2006,2007,2008, 'Total']]
# Out:
#                            Continent        RegName   2006   2007   2008  \
# Afghanistan                     Asia  Southern Asia   3009   2652   2111
# Bangladesh                      Asia  Southern Asia   4014   2897   2939
# Bhutan                          Asia  Southern Asia     10      7     36
# India                           Asia  Southern Asia  33848  28742  28261
# Iran (Islamic Republic of)      Asia  Southern Asia   7480   6974   6475
# Maldives                        Asia  Southern Asia      0      2      1
# Nepal                           Asia  Southern Asia    540    511    581
# Pakistan                        Asia  Southern Asia  13127  10124   8994
# Sri Lanka                       Asia  Southern Asia   4714   4123   4756
#
#                               Total
# Afghanistan                  197931
# Bangladesh                   218718
# Bhutan                        39642
# India                       2097726
# Iran (Islamic Republic of)   549783
# ...

# %%
haiti = df_can.loc['Haiti',[2010,2011,2012,2013]]
haiti.head()
# Out:
# 2010    4744
# 2011    6503
# 2012    5868
# 2013    4152
# Name: Haiti, dtype: object

# %%
haiti.plot()

# %%
import matplotlib.pyplot as plt
haiti.plot()
plt.title('Immegration from Haiti')
plt.xlabel('Years')
plt.ylabel('No. of people')
# Out:
# Text(0, 0.5, 'No. of people')

# %%
years = list(map(int, range(1983,2014)))
years
# Out:
# [1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
India = df_can.loc['India', years]
China = df_can.loc['China', years]
India.head()
China.tail()
# Out:
# 2009    29622
# 2010    30391
# 2011    28502
# 2012    33024
# 2013    34129
# Name: China, dtype: object

# %%
India.plot()
plt.title('Indian Emmigrants to Canada')
plt.xlabel('Years')
plt.ylabel('No. of emmigrants')
plt.show()

# %%
China.plot()
plt.title('Chinese Emmigrants to Canada')
plt.xlabel('Years')
plt.ylabel('No. of emmigrants')
plt.show()

# %%
df_IndChina = df_can.loc[['India','China'], years]
df_IndChina.head()
# Out:
#        1983  1984  1985  1986   1987   1988   1989   1990   1991   1992  ...  \
# India  7338  5704  4211  7150  10189  11522  10343  12041  13734  13673  ...
# China  1863  1527  1816  1960   2643   2758   4323   8076  14255  10846  ...
#
#         2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# India  28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
# China  36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
#
# [2 rows x 31 columns]

# %%
df_IndChina.plot()
plt.title('Indian Emmigrants to Canada')
plt.xlabel('Years')
plt.ylabel('No. of emmigrants')
plt.show()

# %%
df_IndChina = df_IndChina.transpose()
df_IndChina.head()
# Out:
#       India  China
# 1983   7338   1863
# 1984   5704   1527
# 1985   4211   1816
# 1986   7150   1960
# 1987  10189   2643

# %%
df_IndChina.plot()
plt.title('Indian Emmigrants to Canada')
plt.xlabel('Years')
plt.ylabel('No. of emmigrants')
plt.show()

# %%
df_top5=df_can.nlargest(5,'Total')

# %%
df_top5= df_top5[years].transpose()

# %%
df_top5.head()
# Out:
#       India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1983   7338   1863                                              10015
# 1984   5704   1527                                              10170
# 1985   4211   1816                                               9564
# 1986   7150   1960                                               9470
# 1987  10189   2643                                              21337
#
#       Philippines  Pakistan
# 1983         4562       900
# 1984         3801       668
# 1985         3150       514
# 1986         4166       691
# 1987         7360      1072

# %%
df_top5.plot(figsize =(14,8))
plt.title('Top 5 Emmigrant nations')
plt.xlabel('Years')
plt.ylabel('No. of people')

plt.show()

# %%
#week2 Assignment...

df_top5.plot(kind = "area", figsize =(14,8))
plt.title('Top 5 Emmigrant nations')
plt.xlabel('Years')
plt.ylabel('No. of people')

plt.show()
